# %%
x := 5;
# Out:
# 5

# %%
G := Group((1,2,3), (1,15));
# Out:
# Group([ (1,2,3), (1,15) ])

# %%
Size(G);
# Out:
# 24

# %%
Center(G);
# Out:
# Group(())

# %%
JupyterSplashDot("digraph { x -> y; }");

# %%
x := 7
# Out:
# Syntax error: ; expected in stream:1
# ^

# %%
Error("Something went wrong?");
# Out:
# Error, Something went wrong?
